# %% [markdown]
# # Experiment 1:
# ## U-Net: Prediction of Human Pose Masks & Regression Values

# %%
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID";
 
# The GPU id to use, usually either "0" or "1";
os.environ["CUDA_VISIBLE_DEVICES"]="1";

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np 
import numpy as np
from keras.models import *
from keras.layers import *
from keras.optimizers import *
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras import backend as keras
from keras.preprocessing import image
import cv2
from keras.utils import multi_gpu_model
from scipy import ndimage
from keras.utils import to_categorical
from keras.models import load_model
from keras import losses
from keras import backend as K
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Create Training and Validation Sets

# %%
image_adr = 'SMALL_5K_IMAGES/'
mask_adr = 'SMALL_5K_MASKS/'
heatmap_adr = 'SMALL_5K_HEATMAPS/'

#image_adr = 'BIG_18K_IMAGES/'
#mask_adr = 'BIG_18K_MASKS/'

images = sorted(os.listdir(image_adr))
masked = sorted(os.listdir(mask_adr))

# %%
print(len(images))
print(len(masked))
# Out:
# 5000
# 5000

# %%
np.random.seed(23)
order = np.random.permutation(len(images))
X_train = order[:int(0.8*len(order))]
X_valid = order[int(0.8*len(order)):]
print(len(X_train))
print(len(X_valid))
# Out:
# 4000
# 1000

# %% [markdown]
# ***
#
# ## U-Net Model

# %%
smooth = 1e-6

def pixelwise_mse(y_pred, y_true):
    y_pred = K.flatten(y_pred[0,:,:,0])
    y_true = K.flatten(y_true[0,:,:,0])
    return losses.mean_squared_error(y_pred, y_true)

def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true[0,:,:,1])
    y_pred_f = K.flatten(y_pred[0,:,:,1])
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

def dice_loss(y_true, y_pred):
    return 1 - dice_coef(y_true, y_pred)

def dice_coef_hard(y_pred, y_true):
    y_true_f = K.flatten(y_true[0,:,:,1])
    y_pred_f = K.flatten(np.argmax(y_pred[0,:,:,:], axis=-1).astype('float32'))
    intersection = y_true_f * y_pred_f
    score = 2. * K.sum(intersection) / (K.sum(y_true_f) + K.sum(y_pred_f))
    return score

# %%
def create_unet(min_neuron):
    
    inputs = Input((None, None, 3))
    
    conv1 = Conv2D(min_neuron, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(inputs)
    conv1 = Conv2D(min_neuron, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)
    
    conv2 = Conv2D(min_neuron*2, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool1)
    conv2 = Conv2D(min_neuron*2, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv2)
    drop2 = Dropout(0.3)(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(drop2)
    
    conv3 = Conv2D(min_neuron*4, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool2)
    conv3 = Conv2D(min_neuron*4, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv3)
    drop3 = Dropout(0.3)(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(drop3)
    
    conv4 = Conv2D(min_neuron*8, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool3)
    conv4 = Conv2D(min_neuron*8, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv4)
    drop4 = Dropout(0.3)(conv4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(drop4)

    conv5 = Conv2D(min_neuron*16, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool4)
    conv5 = Conv2D(min_neuron*16, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv5)
    drop5 = Dropout(0.3)(conv5)

    up6 = Conv2D(min_neuron*8, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(drop5))
    merge6 = concatenate([drop4,up6], axis = 3)
    conv6 = Conv2D(min_neuron*8, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge6)
    conv6 = Conv2D(min_neuron*8, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv6)
    drop6 = Dropout(0.3)(conv6)
    
    up7 = Conv2D(min_neuron*4, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(drop6))
    merge7 = concatenate([conv3,up7], axis = 3)
    conv7 = Conv2D(min_neuron*4, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge7)
    conv7 = Conv2D(min_neuron*4, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv7)
    drop7 = Dropout(0.3)(conv7)

    up8 = Conv2D(min_neuron*2, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(drop7))
    merge8 = concatenate([conv2,up8], axis = 3)
    conv8 = Conv2D(min_neuron*2, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge8)
    conv8 = Conv2D(min_neuron*2, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv8)
    drop8 = Dropout(0.3)(conv8)

    up9 = Conv2D(min_neuron, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(drop8))
    merge9 = concatenate([conv1,up9], axis = 3)
    conv9 = Conv2D(min_neuron, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge9)
    conv9 = Conv2D(min_neuron, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv9)
    
    mask_out = Conv2D(2, 1, activation='softmax', name='output1')(conv9)
    heatmap_out = Conv2D(1, 1, activation='linear', name='output2')(conv9)   # For HeatMaps
    
    model = Model(inputs=inputs, outputs=[mask_out, heatmap_out])    
    model.compile(optimizer = Adam(lr=2e-5), loss={'output1': dice_loss, 'output2': pixelwise_mse}, metrics={'output1': dice_coef})
    #model.compile(optimizer = Adam(lr=1e-4), loss=pixelwise_mse) # For Heatmaps

    return model

# %%
def generator(X_data, y_data, order):
    
    samples_per_epoch = len(order)
    number_of_batches = samples_per_epoch
    
    counter=0
    
    while 1:
        
        X_batch = cv2.cvtColor(cv2.imread(image_adr + X_data[order[counter]]), cv2.COLOR_BGR2RGB).astype('float32')
        X_batch /= 255
        
        r = X_batch.shape[0]
        c = X_batch.shape[1]
        r_pad = 0
        c_pad = 0
        
        while r % 16 != 0:
            r_pad += 1
            r += 1
            
        while c % 16 != 0:
            c_pad += 1
            c += 1
            
        X_batch = np.pad(X_batch, ((0, r_pad), (0, c_pad), (0, 0)), mode='constant', constant_values=0)
        X_batch = np.expand_dims(X_batch, axis=0)

        
        y_heatmap = cv2.imread(heatmap_adr + y_data[order[counter]], 0).astype('float32')/255*100  # For Heatmaps
        y_heatmap = np.pad(y_heatmap, ((0, r_pad), (0, c_pad)), mode='constant', constant_values=0)
        y_heatmap = np.expand_dims(y_heatmap, -1) # For Heatmap
        y_heatmap = np.expand_dims(y_heatmap, 0)
        
        y_mask = (cv2.imread(mask_adr + y_data[order[counter]], 0) > 200).astype('float32') # For Mask
        y_mask = np.pad(y_mask, ((0, r_pad), (0, c_pad)), mode='constant', constant_values=0)
        y_mask = to_categorical(y_mask, 2) # For Mask
        y_mask = np.expand_dims(y_mask, 0)

        counter += 1
        
        yield X_batch, {'output1': y_mask, 'output2': y_heatmap}

        #restart counter to yeild data in the next epoch as well
        if counter >= number_of_batches:
            counter = 0

# %%
model1 = create_unet(64)
model1.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            (None, None, None, 3 0
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, None, None, 6 1792        input_3[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, None, None, 6 36928       conv2d_45[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_9 (MaxPooling2D)  (None, None, None, 6 0           conv2d_46[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, None, None, 1 73856       max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, None, None, 1 147584      conv2d_47[0][0]
# __________________________________________________________________________________________________
# dropout_15 (Dropout)            (None, None, None, 1 0           conv2d_48[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_10 (MaxPooling2D) (None, None, None, 1 0           dropout_15[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, None, None, 2 295168      max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, None, None, 2 590080      conv2d_49[0][0]
# __________________________________________________________________________________________________
# dropout_16 (Dropout)            (None, None, None, 2 0           conv2d_50[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_11 (MaxPooling2D) (None, None, None, 2 0           dropout_16[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, None, None, 5 1180160     max_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, None, None, 5 2359808     conv2d_51[0][0]
# __________________________________________________________________________________________________
# dropout_17 (Dropout)            (None, None, None, 5 0           conv2d_52[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_12 (MaxPooling2D) (None, None, None, 5 0           dropout_17[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, None, None, 1 4719616     max_pooling2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, None, None, 1 9438208     conv2d_53[0][0]
# __________________________________________________________________________________________________
# dropout_18 (Dropout)            (None, None, None, 1 0           conv2d_54[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_9 (UpSampling2D)  (None, None, None, 1 0           dropout_18[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, None, None, 5 2097664     up_sampling2d_9[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, None, None, 1 0           dropout_17[0][0]
#                                                                  conv2d_55[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, None, None, 5 4719104     concatenate_9[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, None, None, 5 2359808     conv2d_56[0][0]
# __________________________________________________________________________________________________
# dropout_19 (Dropout)            (None, None, None, 5 0           conv2d_57[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_10 (UpSampling2D) (None, None, None, 5 0           dropout_19[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, None, None, 2 524544      up_sampling2d_10[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, None, None, 5 0           conv2d_50[0][0]
#                                                                  conv2d_58[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, None, None, 2 1179904     concatenate_10[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, None, None, 2 590080      conv2d_59[0][0]
# __________________________________________________________________________________________________
# dropout_20 (Dropout)            (None, None, None, 2 0           conv2d_60[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_11 (UpSampling2D) (None, None, None, 2 0           dropout_20[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, None, None, 1 131200      up_sampling2d_11[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, None, None, 2 0           conv2d_48[0][0]
#                                                                  conv2d_61[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, None, None, 1 295040      concatenate_11[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, None, None, 1 147584      conv2d_62[0][0]
# __________________________________________________________________________________________________
# dropout_21 (Dropout)            (None, None, None, 1 0           conv2d_63[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_12 (UpSampling2D) (None, None, None, 1 0           dropout_21[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, None, None, 6 32832       up_sampling2d_12[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, None, None, 1 0           conv2d_46[0][0]
#                                                                  conv2d_64[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, None, None, 6 73792       concatenate_12[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, None, None, 6 36928       conv2d_65[0][0]
# __________________________________________________________________________________________________
# output1 (Conv2D)                (None, None, None, 2 130         conv2d_66[0][0]
# __________________________________________________________________________________________________
# output2 (Conv2D)                (None, None, None, 1 65          conv2d_66[0][0]
# ==================================================================================================
# Total params: 31,031,875
# Trainable params: 31,031,875
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ***
#
# ## Model Training
#
# ### Small Dataset Training

# %%
checkpoint = ModelCheckpoint('model-{epoch:03d}-{val_loss:03f}.h5', verbose=1, 
                             monitor='val_loss', save_best_only=True, mode='auto') 


history = model1.fit_generator(generator(images, masked, X_train),
                              epochs=100,
                              steps_per_epoch = len(X_train),
                              validation_data = generator(images, masked, X_valid),
                              validation_steps = len(X_valid),
                              callbacks=[checkpoint])
# Out:
# Epoch 1/100
# 4000/4000 [==============================] - 248s 62ms/step - loss: 19.9099 - output1_loss: 0.2847 - output2_loss: 19.6252 - output1_dice_coef: 0.7153 - val_loss: 19.4502 - val_output1_loss: 0.2081 - val_output2_loss: 19.2421 - val_output1_dice_coef: 0.7919
#
# Epoch 00001: val_loss improved from inf to 19.45017, saving model to model-001-19.450167.h5
# Epoch 2/100
# 4000/4000 [==============================] - 245s 61ms/step - loss: 18.4842 - output1_loss: 0.1820 - output2_loss: 18.3022 - output1_dice_coef: 0.8180 - val_loss: 18.5262 - val_output1_loss: 0.1727 - val_output2_loss: 18.3535 - val_output1_dice_coef: 0.8273
#
# Epoch 00002: val_loss improved from 19.45017 to 18.52616, saving model to model-002-18.526158.h5
# Epoch 3/100
# 4000/4000 [==============================] - 244s 61ms/step - loss: 17.7439 - output1_loss: 0.1603 - output2_loss: 17.5836 - output1_dice_coef: 0.8397 - val_loss: 17.8467 - val_output1_loss: 0.1563 - val_output2_loss: 17.6903 - val_output1_dice_coef: 0.8437
#
# Epoch 00003: val_loss improved from 18.52616 to 17.84665, saving model to model-003-17.846651.h5
# Epoch 4/100
# 4000/4000 [==============================] - 244s 61ms/step - loss: 17.0860 - output1_loss: 0.1472 - output2_loss: 16.9388 - output1_dice_coef: 0.8528 - val_loss: 17.2611 - val_output1_loss: 0.1500 - val_output2_loss: 17.1111 - val_output1_dice_coef: 0.8500
#
# Epoch 00004: val_loss improved from 17.84665 to 17.26111, saving model to model-004-17.261108.h5
# Epoch 5/100
# 4000/4000 [==============================] - 245s 61ms/step - loss: 16.5104 - output1_loss: 0.1381 - output2_loss: 16.3723 - output1_dice_coef: 0.8619 - val_loss: 16.7194 - val_output1_loss: 0.1437 - val_output2_loss: 16.5757 - val_output1_dice_coef: 0.8563
#
# Epoch 00005: val_loss improved from 17.26111 to 16.71943, saving model to model-005-16.719427.h5
# Epoch 6/100
# 4000/4000 [==============================] - 245s 61ms/step - loss: 15.9772 - output1_loss: 0.1309 - output2_loss: 15.8463 - output1_dice_coef: 0.8691 - val_loss: 16.1958 - val_output1_loss: 0.1348 - val_output2_loss: 16.0610 - val_output1_dice_coef: 0.8652
#
# Epoch 00006: val_loss improved from 16.71943 to 16.19580, saving model to model-006-16.195802.h5
# Epoch 7/100
# 4000/4000 [==============================] - 244s 61ms/step - loss: 15.4901 - output1_loss: 0.1253 - output2_loss: 15.3648 - output1_dice_coef: 0.8747 - val_loss: 15.9046 - val_output1_loss: 0.1318 - val_output2_loss: 15.7728 - val_output1_dice_coef: 0.8682
#
# Epoch 00007: val_loss improved from 16.19580 to 15.90461, saving model to model-007-15.904609.h5
# Epoch 8/100
# 4000/4000 [==============================] - 244s 61ms/step - loss:
100
# 4000/4000 [==============================] - 244s 61ms/step - loss: 6.4116 - output1_loss: 0.0884 - output2_loss: 6.3232 - output1_dice_coef: 0.9116 - val_loss: 15.8155 - val_output1_loss: 0.1057 - val_output2_loss: 15.7099 - val_output1_dice_coef: 0.8943
#
# Epoch 00049: val_loss did not improve from 14.85209
# Epoch 50/100
# 4000/4000 [==============================] - 244s 61ms/step - loss: 6.3069 - output1_loss: 0.0880 - output2_loss: 6.2190 - output1_dice_coef: 0.9120 - val_loss: 15.7653 - val_output1_loss: 0.1060 - val_output2_loss: 15.6592 - val_output1_dice_coef: 0.8940
#
# Epoch 00050: val_loss did not improve from 14.85209
# Epoch 51/100
# 4000/4000 [==============================] - 244s 61ms/step - loss: 6.2005 - output1_loss: 0.0872 - output2_loss: 6.1132 - output1_dice_coef: 0.9128 - val_loss: 15.8598 - val_output1_loss: 0.1041 - val_output2_loss: 15.7557 - val_output1_dice_coef: 0.8959
#
# Epoch 00051: val_loss did not improve from 14.85209
# Epoch 52/100
# 4000/4000 [==============================] - 244s 61ms/step - loss: 6.0889 - output1_loss: 0.0873 - output2_loss: 6.0016 - output1_dice_coef: 0.9127 - val_loss: 15.8035 - val_output1_loss: 0.1061 - val_output2_loss: 15.6973 - val_output1_dice_coef: 0.8939
#
# Epoch 00052: val_loss did not improve from 14.85209
# Epoch 53/100
# 4000/4000 [==============================] - 244s 61ms/step - loss: 5.9906 - output1_loss: 0.0880 - output2_loss: 5.9026 - output1_dice_coef: 0.9120 - val_loss: 15.7764 - val_output1_loss: 0.1053 - val_output2_loss: 15.6712 - val_output1_dice_coef: 0.8947
#
# Epoch 00053: val_loss did not improve from 14.85209
# Epoch 54/100
# 4000/4000 [==============================] - 244s 61ms/step - loss: 5.8898 - output1_loss: 0.0874 - output2_loss: 5.8024 - output1_dice_coef: 0.9126 - val_loss: 15.5290 - val_output1_loss: 0.1055 - val_output2_loss: 15.4235 - val_output1_dice_coef: 0.8945
#
# Epoch 00054: val_loss did not improve from 14.85209
# Epoch 55/100
# 4000/4000 [==============================] - 244s 61ms/step - loss: 5.8139 - output1_loss: 0.0869 - output2_loss: 5.7270 - output1_dice_coef: 0.9131 - val_loss: 15.7533 - val_output1_loss: 0.1035 - val_output2_loss: 15.6498 - val_output1_dice_coef: 0.8965
#
# Epoch 00055: val_loss did not improve from 14.85209
# Epoch 56/100
# 4000/4000 [==============================] - 244s 61ms/step - loss: 5.7034 - output1_loss: 0.0867 - output2_loss: 5.6168 - output1_dice_coef: 0.9133 - val_loss: 15.7954 - val_output1_loss: 0.1034 - val_output2_loss: 15.6919 - val_output1_dice_coef: 0.8966
#
# Epoch 00056: val_loss did not improve from 14.85209
# Epoch 57/100
# 4000/4000 [==============================] - 244s 61ms/step - loss: 5.6097 - output1_loss: 0.0867 - output2_loss: 5.5230 - output1_dice_coef: 0.9133 - val_loss: 15.9681 - val_output1_loss: 0.1043 - val_output2_loss: 15.8638 - val_output1_dice_coef: 0.8957
#
# Epoch 00057: val_loss did not improve from 14.85209
# Epoch 58/100
# 4000/4000 [==============================] - 244s 61ms/step - loss: 5.5359 - output1_loss: 0.0866 - output2_loss: 5.4493 - output1_dice_coef: 0.9134 - val_loss: 15.9265 - val_output1_loss: 0.1028 - val_output2_loss: 15.8237 - val_output1_dice_coef: 0.8972
#
# Epoch 00058: val_loss did not improve from 14.85209
# Epoch 59/100
# 4000/4000 [==============================] - 245s 61ms/step - loss: 5.4438 - output1_loss: 0.0862 - output2_loss: 5.3576 - output1_dice_coef: 0.9138 - val_loss: 15.9797 - val_output1_loss: 0.1040 - val_output2_loss: 15.8757 - val_output1_dice_coef: 0.8960
#
# Epoch 00059: val_loss did not improve from 14.85209
# Epoch 60/100
# 4000/4000 [==============================] - 244s 61ms/step - loss: 5.3928 - output1_loss: 0.0861 - output2_loss: 5.3067 - output1_dice_coef: 0.9139 - val_loss: 15.8906 - val_output1_loss: 0.1048 - val_output2_loss: 15.7858 - val_output1_dice_coef: 0.8952
#
# Epoch 00060: val_loss did not improve from 14.85209
# Epoch 61/100
# 4000/4000 [==============================] - 244s 61ms/step - loss: 5.2944 - output1_loss: 0.0858 - output2_loss: 5.2086 - output1_dice_coef: 0.9142 - val_loss: 15.7702 - val_output1_loss: 0.1044 - val_output2_loss: 15.6658 - val_output1_dice_coef: 0.8956
#
# Epoch 00061: val_loss did not improve from 14.85209
# Epoch 62/100
# 4000/4000 [==============================] - 245s 61ms/step - loss: 5.2086 - output1_loss: 0.0856 - output2_loss: 5.1230 - output1_dice_coef: 0.9144 - val_loss: 15.8017 - val_output1_loss: 0.1063 - val_output2_loss: 15.6953 - val_output1_dice_coef: 0.8937
#
# Epoch 00062: val_loss did not improve from 14.85209
# Epoch 63/100
# 4000/4000 [==============================] - 244s 61ms/step - loss: 5.1303 - output1_loss: 0.0857 - output2_loss: 5.0446 - output1_dice_coef: 0.9143 - val_loss: 15.8031 - val_output1_loss: 0.1033 - val_output2_loss: 15.6998 - val_output1_dice_coef: 0.8967
#
# Epoch 00063: val_loss did not improve from 14.85209
# Epoch 64/100
# 4000/4000 [==============================] - 244s 61ms/step - loss: 5.0385 - output1_loss: 0.0854 - output2_loss: 4.9530 - output1_dice_coef: 0.9146 - val_loss: 15.8992 - val_output1_loss: 0.1030 - val_output2_loss: 15.7962 - val_output1_dice_coef: 0.8970
#
# Epoch 00064: val_loss did not improve from 14.85209
# Epoch 65/100
# 4000/4000 [==============================] - 244s 61ms/step - loss: 4.9898 - output1_loss: 0.0852 - output2_loss: 4.9046 - output1_dice_coef: 0.9148 - val_loss: 15.8199 - val_output1_loss: 0.1036 - val_output2_loss: 15.7163 - val_output1_dice_coef: 0.8964
#
# Epoch 00065: val_loss did not improve from 14.85209
# Epoch 66/100
# 4000/4000 [==============================] - 244s 61ms/step - loss: 4.8927 - output1_loss: 0.0851 - output2_loss: 4.8077 - output1_dice_coef: 0.9149 - val_loss: 16.0067 - val_output1_loss: 0.1038 - val_output2_loss: 15.9028 - val_output1_dice_coef: 0.8962
#
# Epoch 00066: val_loss did not improve from 14.85209
# Epoch 67/100
# 4000/4000 [==============================] - 244s 61ms/step - loss: 4.8319 - output1_loss: 0.0849 - output2_loss: 4.7470 - output1_dice_coef: 0.9151 - val_loss: 15.9147 - val_output1_loss: 0.1044 - val_output2_loss: 15.8103 - val_output1_dice_coef: 0.8956
#
# Epoch 00067: val_loss did not improve from 14.85209
# Epoch 68/100
# 4000/4000 [==============================] - 244s 61ms/step - loss: 4.7657 - output1_loss: 0.0846 - output2_loss: 4.6812 - output1_dice_coef: 0.9154 - val_loss: 15.9471 - val_output1_loss: 0.1015 - val_output2_loss: 15.8457 - val_output1_dice_coef: 0.8985
#
# Epoch 00068: val_loss did not improve from 14.85209
# Epoch 69/100
# 4000/4000 [==============================] - 244s 61ms/step - loss: 4.7011 - output1_loss: 0.0845 - output2_loss: 4.6166 - output1_dice_coef: 0.9155 - val_loss: 16.0532 - val_output1_loss: 0.1037 - val_output2_loss: 15.9495 - val_output1_dice_coef: 0.8963
#
# Epoch 00069: val_loss did not improve from 14.85209
# Epoch 70/100
# 4000/4000 [==============================] - 244s 61ms/step - loss: 4
100
# 4000/4000 [==============================] - 244s 61ms/step - loss: 3.5454 - output1_loss: 0.0819 - output2_loss: 3.4634 - output1_dice_coef: 0.9181 - val_loss: 16.1086 - val_output1_loss: 0.1017 - val_output2_loss: 16.0069 - val_output1_dice_coef: 0.8983
#
# Epoch 00091: val_loss did not improve from 14.85209
# Epoch 92/100
# 4000/4000 [==============================] - 244s 61ms/step - loss: 3.5078 - output1_loss: 0.0813 - output2_loss: 3.4264 - output1_dice_coef: 0.9187 - val_loss: 15.9929 - val_output1_loss: 0.1011 - val_output2_loss: 15.8918 - val_output1_dice_coef: 0.8989
#
# Epoch 00092: val_loss did not improve from 14.85209
# Epoch 93/100
# 4000/4000 [==============================] - 244s 61ms/step - loss: 3.4699 - output1_loss: 0.0814 - output2_loss: 3.3885 - output1_dice_coef: 0.9186 - val_loss: 16.0396 - val_output1_loss: 0.1027 - val_output2_loss: 15.9369 - val_output1_dice_coef: 0.8973
#
# Epoch 00093: val_loss did not improve from 14.85209
# Epoch 94/100
# 4000/4000 [==============================] - 244s 61ms/step - loss: 3.4232 - output1_loss: 0.0817 - output2_loss: 3.3415 - output1_dice_coef: 0.9183 - val_loss: 15.9824 - val_output1_loss: 0.1011 - val_output2_loss: 15.8813 - val_output1_dice_coef: 0.8989
#
# Epoch 00094: val_loss did not improve from 14.85209
# Epoch 95/100
# 4000/4000 [==============================] - 244s 61ms/step - loss: 3.4000 - output1_loss: 0.0813 - output2_loss: 3.3188 - output1_dice_coef: 0.9187 - val_loss: 16.0251 - val_output1_loss: 0.1014 - val_output2_loss: 15.9238 - val_output1_dice_coef: 0.8986
#
# Epoch 00095: val_loss did not improve from 14.85209
# Epoch 96/100
# 4000/4000 [==============================] - 245s 61ms/step - loss: 3.3570 - output1_loss: 0.0812 - output2_loss: 3.2758 - output1_dice_coef: 0.9188 - val_loss: 15.9555 - val_output1_loss: 0.1018 - val_output2_loss: 15.8537 - val_output1_dice_coef: 0.8982
#
# Epoch 00096: val_loss did not improve from 14.85209
# Epoch 97/100
# 4000/4000 [==============================] - 244s 61ms/step - loss: 3.3292 - output1_loss: 0.0809 - output2_loss: 3.2483 - output1_dice_coef: 0.9191 - val_loss: 16.0634 - val_output1_loss: 0.1022 - val_output2_loss: 15.9613 - val_output1_dice_coef: 0.8978
#
# Epoch 00097: val_loss did not improve from 14.85209
# Epoch 98/100
# 4000/4000 [==============================] - 244s 61ms/step - loss: 3.2967 - output1_loss: 0.0809 - output2_loss: 3.2158 - output1_dice_coef: 0.9191 - val_loss: 15.9945 - val_output1_loss: 0.1017 - val_output2_loss: 15.8928 - val_output1_dice_coef: 0.8983
#
# Epoch 00098: val_loss did not improve from 14.85209
# Epoch 99/100
# 4000/4000 [==============================] - 244s 61ms/step - loss: 3.2635 - output1_loss: 0.0806 - output2_loss: 3.1829 - output1_dice_coef: 0.9194 - val_loss: 15.9687 - val_output1_loss: 0.1030 - val_output2_loss: 15.8657 - val_output1_dice_coef: 0.8970
#
# Epoch 00099: val_loss did not improve from 14.85209
# Epoch 100/100
# 4000/4000 [==============================] - 244s 61ms/step - loss: 3.2096 - output1_loss: 0.0805 - output2_loss: 3.1291 - output1_dice_coef: 0.9195 - val_loss: 16.2442 - val_output1_loss: 0.1014 - val_output2_loss: 16.1429 - val_output1_dice_coef: 0.8986
#
# Epoch 00100: val_loss did not improve from 14.85209

# %%
#from IPython.display import SVG
#from keras.utils.vis_utils import model_to_dot
#SVG(model_to_dot(model).create(prog='dot', format='svg'))

# %%
#from keras.utils import plot_model
#plot_model(model, to_file='model_output.png')

# %% [markdown]
# ***
#
# ## Model Save

# %%
#model.save_weights('15ep_softmax_model_BIG.h5')
model1.save('100ep-heatmap-mask-model-newest-08996-161.h5')

# %% [markdown]
# ## Model Load

# %%
dependencies = {
    'dice_loss': dice_loss,
    'dice_coef_hard': dice_coef_hard,
    'dice_coef': dice_coef
}

#model = keras.models.load_model('30ep_FULL_model_SMALL.h5', custom_objects=dependencies)
model = load_model('model-089-0.919240-0.080760.h5', custom_objects=dependencies)
#model = load_model('100ep_FULL_dropout_softmax_model_SMALL.h5', custom_objects=dependencies)

# %% [markdown]
# ***
#
# ## Model Performance
#
# ### Small Dataset

# %%
ad = history.history

f, ax = plt.subplots(2,2, figsize=(18,14))

ax[0,0].plot(ad['loss'], label='Training')
ax[0,0].plot(ad['val_loss'], label='Validation')
ax[0,0].set_title('Loss')
ax[0,0].set_xlabel('Epoch')
ax[0,0].legend()

ax[0,1].plot(ad['output1_loss'], label='Training')
ax[0,1].plot(ad['val_output1_loss'], label='Validation')
ax[0,1].set_title('Dice Loss')
ax[0,1].set_xlabel('Epoch')
ax[0,1].legend()

ax[1,0].plot(ad['output2_loss'], label='Training')
ax[1,0].plot(ad['val_output2_loss'], label='Validation')
ax[1,0].set_title('MSE Loss')
ax[1,0].set_xlabel('Epoch')
ax[1,0].legend()

ax[1,1].plot(ad['output1_dice_coef'], label='Training')
ax[1,1].plot(ad['val_output1_dice_coef'], label='Validation')
ax[1,1].set_title('Dice Coef.')
ax[1,1].set_xlabel('Epoch')
ax[1,1].legend()

# %% [markdown]
# ***
#
# ## Sample Predictions
#
# ### Small Dataset

# %%
image_list = X_valid[40:60]

f, ax = plt.subplots(20,5, figsize=(18,80))
c_ = 0

for i in range(20):
    X_batch = cv2.cvtColor(cv2.imread(image_adr + images[image_list[c_]]), cv2.COLOR_BGR2RGB).astype('float32')
    X_batch /= 255

    r = X_batch.shape[0]
    c = X_batch.shape[1]
    r_pad = 0
    c_pad = 0

    while r % 16 != 0:
        r_pad += 1
        r += 1

    while c % 16 != 0:
        c_pad += 1
        c += 1

    X_batch = np.pad(X_batch, ((0, r_pad), (0, c_pad), (0, 0)), mode='constant', constant_values=0)
    ax[i,0].imshow(X_batch)
    X_batch = np.expand_dims(X_batch, axis=0)

    pred = model1.predict(X_batch)
    pred_1 = np.argmax(pred[0], axis=3)[0]
    pred[1] = (pred[1] - np.min(pred[1]))/(np.max(pred[1])-np.min(pred[1]))

    ax[i,1].imshow(cv2.imread(mask_adr + images[image_list[c_]], 0))
    ax[i,2].imshow(pred_1)
    ax[i,3].imshow(cv2.imread(heatmap_adr + images[image_list[c_]], 0))
    ax[i,4].imshow(np.squeeze(pred[1]))

    c_ += 1

for j in range(20):
    _ = ax[j,0].set_ylabel('Image')
    _ = ax[j,1].set_ylabel('Mask R-CNN')
    _ = ax[j,2].set_ylabel('U-Net: Mask')
    _ = ax[j,3].set_ylabel('OpenPose')
    _ = ax[j,4].set_ylabel('U-Net: Heatmap')
